# %% [markdown]
# #ANÁLISIS DE LOS PREMIOS OSCAR 1927 - 2023

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## CARGA Y LIMPIEZA DEL DATA SET

# %%
#Carga de Librería Pandas para limpieza y carga del Data Set

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/the_oscar_award 1927 -2023.csv",delimiter = ",", on_bad_lines='skip')
df.head(5)
# Out:
#    year_film  year_ceremony  ceremony category                 name  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess
# 1       1927           1928         1    ACTOR        Emil Jannings
# 2       1927           1928         1  ACTRESS       Louise Dresser
# 3       1927           1928         1  ACTRESS         Janet Gaynor
# 4       1927           1928         1  ACTRESS       Gloria Swanson
#
#                film  winner
# 0         The Noose   False
# 1  The Last Command    True
# 2   A Ship Comes In   False
# 3        7th Heaven    True
# 4    Sadie Thompson   False

# %%
#Descripción general de los tipos de datos que contiene cada variable

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10759 entries, 0 to 10758
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year_film      10759 non-null  int64
#  1   year_ceremony  10759 non-null  int64
#  2   ceremony       10759 non-null  int64
#  3   category       10759 non-null  object
#  4   name           10756 non-null  object
#  5   film           10449 non-null  object
#  6   winner         10759 non-null  bool
# dtypes: bool(1), int64(3), object(3)
# memory usage: 515.0+ KB

# %%
#Revisamos valores nulos

df.isnull().sum()
# Out:
# year_film          0
# year_ceremony      0
# ceremony           0
# category           0
# name               3
# film             310
# winner             0
# dtype: int64

# %%
#Revisamos valores ausentes

df.isna().sum()
# Out:
# year_film          0
# year_ceremony      0
# ceremony           0
# category           0
# name               3
# film             310
# winner             0
# dtype: int64

# %%
#Eliminamos valoes ausentes y confirmamos que esté completo el Data Set

df = df.dropna()
df.isna().sum()
# Out:
# year_film        0
# year_ceremony    0
# ceremony         0
# category         0
# name             0
# film             0
# winner           0
# dtype: int64

# %%
#Visualizamos el Data Set , está ordenado por año de manera ascendente.

df.head(10)
# Out:
#    year_film  year_ceremony  ceremony        category  \
# 0       1927           1928         1           ACTOR
# 1       1927           1928         1           ACTOR
# 2       1927           1928         1         ACTRESS
# 3       1927           1928         1         ACTRESS
# 4       1927           1928         1         ACTRESS
# 5       1927           1928         1   ART DIRECTION
# 6       1927           1928         1   ART DIRECTION
# 7       1927           1928         1   ART DIRECTION
# 8       1927           1928         1  CINEMATOGRAPHY
# 9       1927           1928         1  CINEMATOGRAPHY
#
#                       name               film  winner
# 0      Richard Barthelmess          The Noose   False
# 1            Emil Jannings   The Last Command    True
# 2           Louise Dresser    A Ship Comes In   False
# 3             Janet Gaynor         7th Heaven    True
# 4           Gloria Swanson     Sadie Thompson   False
# ...

# %%
#Visualización de los últimos datos en el Data Set

df.tail(10)
# Out:
#        year_film  year_ceremony  ceremony                       category  \
# 10749       2022           2023        95   Writing (Adapted Screenplay)
# 10750       2022           2023        95   Writing (Adapted Screenplay)
# 10751       2022           2023        95   Writing (Adapted Screenplay)
# 10752       2022           2023        95   Writing (Adapted Screenplay)
# 10753       2022           2023        95   Writing (Adapted Screenplay)
# 10754       2022           2023        95  Writing (Original Screenplay)
# 10755       2022           2023        95  Writing (Original Screenplay)
# 10756       2022           2023        95  Writing (Original Screenplay)
# 10757       2022           2023        95  Writing (Original Screenplay)
# 10758       2022           2023        95  Writing (Original Screenplay)
#
#                                                     name  \
# 10749  Screenplay - Edward Berger, Lesley Paterson & ...
# ...

# %%
#Estandarizamos la columna "category" para que sólo contenga MAYÚSUCLAS cómo los primeros registros.
df["category"] = df["category"].str.upper()
df["category"]
# Out:
# 0                                ACTOR
# 1                                ACTOR
# 2                              ACTRESS
# 3                              ACTRESS
# 4                              ACTRESS
#                      ...
# 10754    WRITING (ORIGINAL SCREENPLAY)
# 10755    WRITING (ORIGINAL SCREENPLAY)
# 10756    WRITING (ORIGINAL SCREENPLAY)
# 10757    WRITING (ORIGINAL SCREENPLAY)
# 10758    WRITING (ORIGINAL SCREENPLAY)
# Name: category, Length: 10449, dtype: object

# %%
#Datos Generales

df.describe()
# Out:
#           year_film  year_ceremony      ceremony
# count  10449.000000   10449.000000  10449.000000
# mean    1976.255431    1977.255431     49.277730
# std       26.967299      26.967299     26.929151
# min     1927.000000    1928.000000      1.000000
# 25%     1952.000000    1953.000000     25.000000
# 50%     1976.000000    1977.000000     49.000000
# 75%     2000.000000    2001.000000     73.000000
# max     2022.000000    2023.000000     95.000000

# %%
#Atributos del DataFrame
print(df.columns)
print(df.shape)
# Out:
# Index(['year_film', 'year_ceremony', 'ceremony', 'category', 'name', 'film',
#        'winner'],
#       dtype='object')
# (10449, 7)

# %% [markdown]
# ##ALGUNOS DATOS INTERESANTES

# %% [markdown]
# ###Películas ganadoras de premios Oscar

# %%
Películas_Ganadoras = df[df["winner"] == True]
Películas_Ganadoras
# Out:
#        year_film  year_ceremony  ceremony                       category  \
# 1           1927           1928         1                          ACTOR
# 3           1927           1928         1                        ACTRESS
# 6           1927           1928         1                  ART DIRECTION
# 9           1927           1928         1                 CINEMATOGRAPHY
# 10          1927           1928         1                 CINEMATOGRAPHY
# ...          ...            ...       ...                            ...
# 10734       2022           2023        95       SHORT FILM (LIVE ACTION)
# 10743       2022           2023        95                          SOUND
# 10745       2022           2023        95                 VISUAL EFFECTS
# 10753       2022           2023        95   WRITING (ADAPTED SCREENPLAY)
# 10755       2022           2023        95  WRITING (ORIGINAL SCREENPLAY)
#
#                                                     name  \
# ...

# %% [markdown]
# ###Películas que han obtenido más premios Oscar

# %%
Top10_Ganadoras = Películas_Ganadoras[["film","winner","year_film"]].groupby(["film","year_film"]).count()
Top10_Ganadoras = Top10_Ganadoras.sort_values("winner", ascending=False )
Top10_Ganadoras.head(10)
# Out:
#                                                          winner
# film                                          year_film
# Titanic                                       1997           11
# The Lord of the Rings: The Return of the King 2003           11
# Ben-Hur                                       1959           11
# West Side Story                               1961           10
# Gigi                                          1958            9
# The English Patient                           1996            9
# The Last Emperor                              1987            9
# Gone with the Wind                            1939            8
# Cabaret                                       1972            8
# My Fair Lady                                  1964            8

# %%
#Ajuste de indice y columnas
Top10_Ganadoras = pd.DataFrame(Top10_Ganadoras.head(10))
Top10_Ganadoras = Top10_Ganadoras.reset_index()
Top10_Ganadoras.columns
# Out:
# Index(['film', 'year_film', 'winner'], dtype='object')

# %%
#Gráfico

sns.set_style("dark")
sns.set_context("talk")
plt.figure(figsize=(10, 6))

ax = plt.subplot()

sns.barplot(x='film', y='winner', data=Top10_Ganadoras, palette = ["black","red"])

#Poner título a mi gráfico
ax.set_title('PELÍCULAS QUE HAN OBTENIDO MÁS PREMIOS OSCAR EN LA HISTORIA',fontsize=18, fontweight='bold')


#Nombrar y modificar eje X y eje Y
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_xlabel('PELÍCULAS GANADORAS', fontsize=14)
ax.set_ylabel('NÚMERO DE PREMIOS OSCAR GANADOS', fontsize=14)

#Agregar valores a las barras
for i in ax.containers:
    ax.bar_label(i, label_type='edge', fontsize=12)

#Guardar mi gráfico
plt.savefig('gráfico1.png')

#Mostrar gráfico
plt.show()

# %% [markdown]
# ###Películas con mayor número de nominaciones en los premios Oscar

# %%
Top10_Nominaciones = df[["film","winner","year_film"]].groupby(["film","year_film"]).count()
Top10_Nominaciones = Top10_Nominaciones.sort_values("winner", ascending=False )
Top10_Nominaciones.head(10)
# Out:
#                                                winner
# film                                year_film
# Titanic                             1997           14
# La La Land                          2016           14
# All about Eve                       1950           14
# Mary Poppins                        1964           13
# Gone with the Wind                  1939           13
# Shakespeare in Love                 1998           13
# Forrest Gump                        1994           13
# The Curious Case of Benjamin Button 2008           13
# Who's Afraid of Virginia Woolf?     1966           13
# Chicago                             2002           13

# %%
#Ajuste de indice y columnas
Top10_Nominaciones = pd.DataFrame(Top10_Nominaciones.head(10))
Top10_Nominaciones = Top10_Nominaciones.reset_index()
Top10_Nominaciones.columns
# Out:
# Index(['film', 'year_film', 'winner'], dtype='object')

# %%
#Gráfico

sns.set_style("dark")
sns.set_context("talk")
plt.figure(figsize=(10, 6))

ax = plt.subplot()

sns.barplot(x='film', y='winner', data=Top10_Nominaciones, palette = ["gray","red"])

#Poner título a mi gráfico
ax.set_title('PELÍCULAS QUE HAN OBTENIDO MÁS NOMINACIONES A LOS PREMIOS OSCAR EN LA HISTORIA',fontsize=18, fontweight='bold')


#Nombrar y modificar eje X y eje Y
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_xlabel('PELÍCULAS NOMINADAS', fontsize=14)
ax.set_ylabel('NÚMERO DE NOMINACIONES', fontsize=14)

#Agregar valores a las barras
for i in ax.containers:
    ax.bar_label(i, label_type='edge', fontsize=12)

#Guardar mi gráfico
plt.savefig('gráfico2.png')

#Mostrar gráfico
plt.show()

# %% [markdown]
# ###Películas con más nominaciones y los premios ganados

# %%
Lista_Nominadas = (list(Top10_Nominaciones["film"]))
Número_Ganadas = Películas_Ganadoras[Películas_Ganadoras["film"].isin(Lista_Nominadas)]
Número_Ganadas = Número_Ganadas[["film","winner"]].groupby("film").count()
Número_Ganadas = Número_Ganadas.sort_values("film", ascending = True)
Número_Ganadas = Número_Ganadas.reset_index()
Número_Ganadas
# Out:
#                                   film  winner
# 0                        All about Eve       6
# 1                              Chicago       6
# 2                         Forrest Gump       6
# 3                   Gone with the Wind       8
# 4                           La La Land       6
# 5                         Mary Poppins       5
# 6                  Shakespeare in Love       7
# 7  The Curious Case of Benjamin Button       3
# 8                              Titanic      12
# 9      Who's Afraid of Virginia Woolf?       5

# %%
Top10_Nom_Ganadas = Top10_Nominaciones.rename(columns = {'winner' : 'nomination'}, inplace = True)
Top10_Nom_Ganadas = Top10_Nominaciones.sort_values("film")
Top10_Nom_Ganadas = Top10_Nom_Ganadas.reset_index()
Top10_Nom_Ganadas
# Out:
#    index                                 film  year_film  nomination
# 0      2                        All about Eve       1950          14
# 1      9                              Chicago       2002          13
# 2      6                         Forrest Gump       1994          13
# 3      4                   Gone with the Wind       1939          13
# 4      1                           La La Land       2016          14
# 5      3                         Mary Poppins       1964          13
# 6      5                  Shakespeare in Love       1998          13
# 7      7  The Curious Case of Benjamin Button       2008          13
# 8      0                              Titanic       1997          14
# 9      8      Who's Afraid of Virginia Woolf?       1966          13

# %%
Top10_Nom_Ganadas["Real_winners"] = Número_Ganadas["winner"]
Top10_Nom_Ganadas
# Out:
#    index                                 film  year_film  nomination  \
# 0      2                        All about Eve       1950          14
# 1      9                              Chicago       2002          13
# 2      6                         Forrest Gump       1994          13
# 3      4                   Gone with the Wind       1939          13
# 4      1                           La La Land       2016          14
# 5      3                         Mary Poppins       1964          13
# 6      5                  Shakespeare in Love       1998          13
# 7      7  The Curious Case of Benjamin Button       2008          13
# 8      0                              Titanic       1997          14
# 9      8      Who's Afraid of Virginia Woolf?       1966          13
#
#    Real_winners
# 0             6
# 1             6
# 2             6
# 3             8
# 4             6
# 5             5
# 6             7
# 7             3
# 8            12
# 9             5

# %%
#Gráfico

sns.set_style("dark")
sns.set_context("talk")
plt.figure(figsize=(12, 6))

ax = plt.subplot()

sns.barplot(x='film', y='nomination', data=Top10_Nom_Ganadas, color = "red")
sns.barplot(x='film', y='Real_winners', data=Top10_Nom_Ganadas, color ="black")

#Poner título a mi gráfico
ax.set_title('PELÍCULAS QUE HAN OBTENIDO MÁS NOMINACIONES Y SUS PREMIOS GANADOS',fontsize=18, fontweight='bold')


#Nombrar y modificar eje X y eje Y
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_xlabel('PELÍCULAS', fontsize=14)
ax.set_ylabel('NÚMERO DE NNOMINACIONES/OSCAR', fontsize=14)

#Agregar valores a las barras
for i in ax.containers:
    ax.bar_label(i, label_type='edge', fontsize=12)



#Guardar mi gráfico
plt.savefig('gráficoNom_Ganadas.png')

#Mostrar gráfico
plt.show()

# %% [markdown]
# ###Películas que ganaron todos los premios a los que fueron nominadas

# %%
Premios = Películas_Ganadoras[["film","winner","year_film"]].groupby(["film","year_film"]).count()
Nominaciones = df[["film","winner","year_film"]].groupby(["film","year_film"]).count()

Premios["Número_Nominaciones"] = Nominaciones["winner"]


Top10_Ganadoras_Nominadas = Premios[Premios["winner"] == Premios["Número_Nominaciones"]].sort_values("winner", ascending = False)
Top10_Ganadoras_Nominadas = Top10_Ganadoras_Nominadas.head(10)
Top10_Ganadoras_Nominadas
# Out:
#                                                          winner  \
# film                                          year_film
# The Lord of the Rings: The Return of the King 2003           11
# The Last Emperor                              1987            9
# Gigi                                          1958            9
# It Happened One Night                         1934            5
# The Matrix                                    1999            4
# Jurassic Park                                 1993            3
# CODA                                          2021            3
# Grand Prix                                    1966            3
# The Bourne Ultimatum                          2007            3
# The Usual Suspects                            1995            2
#
#                                                          Número_Nominaciones
# film                                          year_film
# ...

# %%
#Ajuste de indice y columnas
Top10_Ganadoras_Nominadas = Top10_Ganadoras.reset_index()
Top10_Ganadoras_Nominadas.columns
# Out:
# Index(['index', 'film', 'year_film', 'winner'], dtype='object')

# %%
#Gráfico

sns.set_style("dark")
sns.set_context("talk")
plt.figure(figsize=(10, 6))

ax = plt.subplot()

sns.barplot(x='film', y='winner', data=Top10_Ganadoras_Nominadas, color = "red")

#Poner título a mi gráfico
ax.set_title('PELÍCULAS QUE HAN GANADO TODOS LOS PREMIOS A LAS QUE FUERON NOMINADAS',fontsize=18, fontweight='bold')


#Nombrar y modificar eje X y eje Y
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_xlabel('PELÍCULAS NOMINADAS/GANADORAS', fontsize=14)
ax.set_ylabel('NÚMERO DE PREMIOS OSCAR GANADOS', fontsize=14)

#Agregar valores a las barras
for i in ax.containers:
    ax.bar_label(i, label_type='edge', fontsize=12)

#Guardar mi gráfico
plt.savefig('gráfico3.png')

#Mostrar gráfico
plt.show()

# %% [markdown]
# ### Últimas 10 películas ganadoras de la categoría "Mejor Película"

# %%
Ultimas_10Mejores = Películas_Ganadoras[Películas_Ganadoras["category"] == "BEST PICTURE"]
Ultimas_10Mejores[["year_ceremony","film"]].tail(10)
# Out:
#        year_ceremony                                             film
# 9594            2014                                 12 Years a Slave
# 9714            2015  Birdman or (The Unexpected Virtue of Ignorance)
# 9845            2016                                        Spotlight
# 9970            2017                                        Moonlight
# 10095           2018                               The Shape of Water
# 10219           2019                                       Green Book
# 10350           2020                                         Parasite
# 10474           2021                                        Nomadland
# 10591           2022                                             CODA
# 10718           2023                Everything Everywhere All at Once

# %% [markdown]
# ###Nominaciones para los premios Oscar 2023

# %%
Nominaciones_2023 = df[["year_film","film","category", "name","winner"]]
Nominaciones_2023 = Nominaciones_2023[Nominaciones_2023["year_film"] == 2022]
Nominaciones_2023
# Out:
#        year_film                               film  \
# 10639       2022                              Elvis
# 10640       2022          The Banshees of Inisherin
# 10641       2022                          The Whale
# 10642       2022                           Aftersun
# 10643       2022                             Living
# ...          ...                                ...
# 10754       2022          The Banshees of Inisherin
# 10755       2022  Everything Everywhere All at Once
# 10756       2022                      The Fabelmans
# 10757       2022                                Tár
# 10758       2022                Triangle of Sadness
#
#                             category  \
# 10639        ACTOR IN A LEADING ROLE
# 10640        ACTOR IN A LEADING ROLE
# 10641        ACTOR IN A LEADING ROLE
# 10642        ACTOR IN A LEADING ROLE
# 10643        ACTOR IN A LEADING ROLE
# ...                              ...
# 10754  WRITING (ORIGINAL SCREENPLAY)
# ...

# %% [markdown]
# ###Ganadores de premios Oscar 2023

# %%
Ganadores_2023 = Nominaciones_2023[Nominaciones_2023["winner"]==True]
Ganadores_2023
# Out:
#        year_film                                      film  \
# 10641       2022                                 The Whale
# 10648       2022         Everything Everywhere All at Once
# 10653       2022         Everything Everywhere All at Once
# 10657       2022         Everything Everywhere All at Once
# 10659       2022            Guillermo del Toro's Pinocchio
# 10664       2022            All Quiet on the Western Front
# 10670       2022            Black Panther: Wakanda Forever
# 10675       2022         Everything Everywhere All at Once
# 10683       2022                                   Navalny
# 10684       2022                   The Elephant Whisperers
# 10691       2022         Everything Everywhere All at Once
# 10694       2022            All Quiet on the Western Front
# 10703       2022                                 The Whale
# 10704       2022            All Quiet on the Western Front
# 10712       2022                                       RRR
# ...

# %% [markdown]
# ###Top de ganadores 2023

# %%
Top_Ganadores2023 = Ganadores_2023[["film","winner"]].groupby("film").count()
Top_Ganadores2023 = Top_Ganadores2023.sort_values("winner",ascending = False)
Top_Ganadores2023
# Out:
#                                           winner
# film
# Everything Everywhere All at Once              7
# All Quiet on the Western Front                 4
# The Whale                                      2
# An Irish Goodbye                               1
# Avatar: The Way of Water                       1
# Black Panther: Wakanda Forever                 1
# Guillermo del Toro's Pinocchio                 1
# Navalny                                        1
# RRR                                            1
# The Boy, the Mole, the Fox and the Horse       1
# The Elephant Whisperers                        1
# Top Gun: Maverick                              1
# Women Talking                                  1

# %%
#Ajuste de indice y columnas
Top_Ganadores2023 = Top_Ganadores2023.reset_index()
Top_Ganadores2023.columns
# Out:
# Index(['film', 'winner'], dtype='object')

# %%
categorias = list(Top_Ganadores2023["film"])
valores = list(Top_Ganadores2023["winner"])

#Set para el doughnut
fig, ax = plt.subplots()
fig.set_size_inches(8, 8)

#Gráfico
ax.pie(valores, labels=categorias, colors=sns.color_palette('dark'), wedgeprops={'width': 0.5})
circulo_central = plt.Circle((0,0), 0.3, color='white')
ax.add_artist(circulo_central)

#Título
ax.set_title('GANADORES DE PREMIOS OSCAR 2023')
ax.axis('equal')

#Guardar mi gráfico
plt.savefig('gráfico4.png')

plt.show()
